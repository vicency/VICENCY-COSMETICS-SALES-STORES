# %% [markdown]
# ` VICENCY COSMETICS SALES STORES`

# %%
# import your libariers
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# load your dataset
df = pd.read_csv(r"C:\Users\user\Desktop\analysis\cosmetics.csv")

# check the rows
df.head()
# Out:
#    Sales Person      Country                  Product        Date  Amount ($)  \
# 0   Lucas Verma       Canada            Aloe Vera Gel  2022-04-30     7897.13
# 1   Ethan Reddy           UK            Aloe Vera Gel  2022-01-25    16376.88
# 2  Ananya Gupta        India        Body Butter Cream  2022-08-22     5599.68
# 3  Ananya Gupta  New Zealand  Salicylic Acid Cleanser  2022-08-26     2966.47
# 4   Sophia Nair           UK        Body Butter Cream  2022-05-19     6828.68
#
#    Boxes Shipped
# 0            358
# 1            449
# 2            264
# 3            144
# 4            484

# %%
# check for missing values
df.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount ($)       0
# Boxes Shipped    0
# dtype: int64

# %%
# check for dulicates
df.duplicated().sum()
# Out:
# 0

# %%
# check for general info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   374 non-null    object
#  1   Country        374 non-null    object
#  2   Product        374 non-null    object
#  3   Date           374 non-null    object
#  4   Amount ($)     374 non-null    float64
#  5   Boxes Shipped  374 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.7+ KB

# %%
# convert date to python date
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ` EXPLORATORY DATA ANALYSIS `

# %%
# sta analysis
df.describe().T
# Out:
#                count                           mean                  min  \
# Date             374  2022-05-04 00:38:30.160427776  2022-01-01 00:00:00
# Amount ($)     374.0                    7778.353262               119.82
# Boxes Shipped  374.0                     249.072193                 10.0
#
#                                25%                  50%                  75%  \
# Date           2022-03-15 00:00:00  2022-05-02 00:00:00  2022-06-28 18:00:00
# Amount ($)                 3325.25             6513.655           11331.8975
# Boxes Shipped                140.0                246.0                364.0
#
#                                max          std
# Date           2022-08-30 00:00:00          NaN
# Amount ($)                23977.48  5655.378093
# Boxes Shipped                499.0   144.235296

# %%
# check countries info
df['Country'].value_counts()
# Out:
# Country
# USA            75
# New Zealand    73
# Australia      70
# UK             61
# India          48
# Canada         47
# Name: count, dtype: int64

# %%
# check product category 
df['Product'].unique().tolist()
# Out:
# ['Aloe Vera Gel',
#  'Body Butter Cream',
#  'Salicylic Acid Cleanser',
#  'Lip Balm Pack',
#  'Rose Water Toner',
#  'Tea Tree Moisturizer',
#  'Face Sheet Masks',
#  'Hair Repair Oil',
#  'Vitamin C Cream',
#  'Niacinamide Toner',
#  'Under Eye Cream',
#  'Hydrating Face Serum',
#  'Charcoal Face Wash',
#  'Anti-Aging Serum',
#  'SPF 50 Sunscreen']

# %%
# how many sales rep in total
df['Sales Person'].unique().tolist()
# Out:
# ['Lucas Verma',
#  'Ethan Reddy',
#  'Ananya Gupta',
#  'Sophia Nair',
#  'Isabella Roy',
#  'Noah Mehta',
#  "Olivia D'Souza",
#  'Ava Sharma',
#  'Liam Patel',
#  'Mason Kapoor']

# %% [markdown]
# ` SALES PERSON's PERFORMANCE OVERTIME `

# %%
# sales performance in terms of total sales by sales person
perf = df.groupby('Sales Person')[['Amount ($)','Boxes Shipped']].sum().sort_values(by='Amount ($)',ascending=False)
perf
# Out:
#                 Amount ($)  Boxes Shipped
# Sales Person
# Olivia D'Souza   387405.91          12619
# Sophia Nair      319887.82          10473
# Isabella Roy     302087.60           9116
# Ethan Reddy      298595.61           8814
# Lucas Verma      295166.91           9330
# Ananya Gupta     293204.67           9669
# Noah Mehta       272188.08           9403
# Liam Patel       270960.55           8513
# Ava Sharma       246174.28           7849
# Mason Kapoor     223432.69           7367

# %%
# plot the sales performace chart in stacked bar format
plt.figure(figsize=(10,6))
plt.bar(perf.index,perf['Amount ($)'],color='skyblue',label='Amount ($)')
plt.bar(perf.index, perf['Boxes Shipped'], color='lightcoral', bottom=perf['Amount ($)'], label='Boxes Shipped')
plt.xlabel("Sales Person")
plt.ylabel("Total Sales Amount ($)")
plt.title("Sales Performance by Sales Person") 
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# TOTAL SALES PER COUNTRY
con = df.groupby(['Country'])['Amount ($)'].sum().sort_values(ascending=False)
con
# Out:
# Country
# USA            628487.86
# New Zealand    557059.85
# Australia      505497.64
# UK             497061.54
# Canada         374562.31
# India          346434.92
# Name: Amount ($), dtype: float64

# %%
# plot the total sales per country
plt.figure(figsize=(10,6))
plt.bar(con.index, con.values, color='RED',)
plt.title("Total Sales per Country")
plt.xlabel("Country")
plt.ylabel("Total Sales Per Counrty")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ` MONTHLY SALES OVERTIME `

# %%
# monthly sales performance
# create a month column and extract the month from date
df['Month'] = df['Date'].dt.to_period('M')

# %%
# extract month name from date
df['Month'] =df['Date'].dt.month_name()
# check
df.head()
# Out:
#    Sales Person      Country                  Product       Date  Amount ($)  \
# 0   Lucas Verma       Canada            Aloe Vera Gel 2022-04-30     7897.13
# 1   Ethan Reddy           UK            Aloe Vera Gel 2022-01-25    16376.88
# 2  Ananya Gupta        India        Body Butter Cream 2022-08-22     5599.68
# 3  Ananya Gupta  New Zealand  Salicylic Acid Cleanser 2022-08-26     2966.47
# 4   Sophia Nair           UK        Body Butter Cream 2022-05-19     6828.68
#
#    Boxes Shipped    Month
# 0            358    April
# 1            449  January
# 2            264   August
# 3            144   August
# 4            484      May

# %%
# extract year from date
df['Year'] = df['Date'].dt.year
# check
df.head()
# Out:
#    Sales Person      Country                  Product       Date  Amount ($)  \
# 0   Lucas Verma       Canada            Aloe Vera Gel 2022-04-30     7897.13
# 1   Ethan Reddy           UK            Aloe Vera Gel 2022-01-25    16376.88
# 2  Ananya Gupta        India        Body Butter Cream 2022-08-22     5599.68
# 3  Ananya Gupta  New Zealand  Salicylic Acid Cleanser 2022-08-26     2966.47
# 4   Sophia Nair           UK        Body Butter Cream 2022-05-19     6828.68
#
#    Boxes Shipped    Month  Year
# 0            358    April  2022
# 1            449  January  2022
# 2            264   August  2022
# 3            144   August  2022
# 4            484      May  2022

# %%
#  check year period
df['Year'].nunique()
# Out:
# 1

# %%
# group sales by month
trend = df.groupby('Month')['Amount ($)'].sum().sort_values(ascending=False)
trend
# Out:
# Month
# March       484101.59
# April       452650.04
# May         396609.09
# June        367001.65
# January     359762.51
# July        359655.73
# August      275298.95
# February    214024.56
# Name: Amount ($), dtype: float64

# %%
# plot info in chart
plt.figure(figsize=(8,4))
plt.plot(trend.index, trend.values, marker='*', linestyle='-', color='GREEN')
plt.xlabel("Month")
plt.ylabel("Total Sales  ($)")
plt.title("Monthly Sales Trend") 
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ` PRODUCT ANALYSIS `

# %%
# Top selling product by country
top_products = df.groupby(['Country', 'Product'])['Amount ($)'].sum().reset_index()
top_products = top_products.sort_values(by=['Country', 'Amount ($)'], ascending=[True,False])
top_products = top_products.groupby('Country').head(1)
top_products
# Out:
#         Country               Product  Amount ($)
# 5     Australia       Hair Repair Oil    91002.87
# 28       Canada       Under Eye Cream    59336.49
# 31        India      Anti-Aging Serum    39111.02
# 55  New Zealand      SPF 50 Sunscreen    87897.03
# 66           UK  Hydrating Face Serum    75719.24
# 76          USA      Anti-Aging Serum   113821.81

# %%
# plot a donut chart for top product by country
plt.figure(figsize=(5,5))
plt.pie(top_products['Amount ($)'], labels=top_products['Product'], autopct= '%1.1f%%', startangle=140)
plt.axis("equal") # equal aspect ratio ensures that pie is drawn as a circle
plt.title("Top selling product by Country(Donut chart)") 
plt.legend(top_products['Country'])
plt.show()

# %% [markdown]
# ` KPI `

# %%
# measur KPIs
kpi = {
     'Total Sales': df['Amount ($)'].sum(),
     'Total Boxes Shipped': df['Boxes Shipped'].sum(),
     'Unique Products Sold': df['Product'].nunique(),
     'Total Countries': df['Country'].nunique(),
     'Total Sales Persons': df['Sales Person'].nunique()
}

# %%
kpi.items()
# Out:
# dict_items([('Total Sales', 2909104.12), ('Total Boxes Shipped', 93153), ('Unique Products Sold', 15), ('Total Countries', 6), ('Total Sales Persons', 10)])

# %%
for key, value in kpi.items():
    print(key,value)
# Out:
# Total Sales 2909104.12
# Total Boxes Shipped 93153
# Unique Products Sold 15
# Total Countries 6
# Total Sales Persons 10
